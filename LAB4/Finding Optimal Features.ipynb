# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate

from sklearn.tree import DecisionTreeClassifier

from sklearn.feature_selection import SelectKBest, chi2

from sklearn.ensemble import ExtraTreesClassifier

from sklearn.neural_network import MLPClassifier

from sklearn.metrics import classification_report

import matplotlib.pyplot as plt

# %% [markdown]
# # Иморт данных
# ```specter``` и ```mask``` имеют тип ```numpy.ndarray```. Размеры 512, 512, 237

# %%
specter = np.load('12.npy')
mask = np.load('12_mask.npy')

# %% [markdown]
# **Создание тренировочных и тестовых выборок для дальнейшей _обыкновенной_ классификации.** Код взят из методички

# %%
x_train = []
y_train = []
x_test = []
y_test = []

height = specter.shape[0]
width = specter.shape[1]
ordered_positions = np.array(np.meshgrid(np.arange(height), np.arange(width))).T.reshape(-1, 2)

train_indices, test_indices = train_test_split(ordered_positions, train_size=0.05, shuffle=True)

for idx in train_indices:
    x_train.append(specter[idx[0], idx[1], ::])
    y_train.append(mask[idx[0], idx[1]])    
    
for idx in test_indices:
    x_test.append(specter[idx[0], idx[1], ::])
    y_test.append(mask[idx[0], idx[1]])    
    
x_train = np.array(x_train, copy=False)
y_train = np.array(y_train, copy=False)
x_test = np.array(x_test, copy=False)
y_test = np.array(y_test, copy=False)

# %%
x_train.shape
# Out:
# (13107, 237)

# %% [markdown]
# Всего имеется 237 признаков. В тренировочной выборке 13107 экземпляров, а в тестовой 249037. Выборки не являются типом ```list```!
#
# **Попробуем создать и протестировать классификатор со всеми признаками** с применением кросс-валидации.

# %%
clf = DecisionTreeClassifier()
cvs = cross_val_score(clf, x_train, y_train, cv=5)
cvs
# Out:
# array([0.7238749 , 0.71815408, 0.7344525 , 0.71384968, 0.72338802])

# %% [markdown]
# Эксперементировать нужно с различным количетсвом выбранных признаков. **Нужно будет создать функцию!!!**. Принимать она должна диапазон выбранных признаков, а возвращать точность модели.

# %% [markdown]
# # Нахождение оптимальных признаков для классификации
# Для начала попробуем найти оптимальные признаки с помощью ```SelectKBest```.
#
# Следует создать **DataFrame**, имеющихся тренировочных данных.

# %%
names = []
for i in range(len(x_train[0])):
    names.append(i)

x = pd.DataFrame(x_train, columns = names)
y = pd.DataFrame(y_train)

# %%
selecter = SelectKBest(score_func=chi2)
fit = selecter.fit(x.values, y.values)
all_features = pd.DataFrame(data=fit.scores_, index=x.columns, columns=['score'])
all_features['number'] = pd.Series(range(x.shape[1]), index=all_features.index)

# %% [markdown]
# Класс. В ```all_features``` получили оценку значимости всех признаков тренировочной выборки. Теперь нужно выбрать из них только самые лучшие.

# %%
best_features = all_features.nlargest(238, "score")

# %% [markdown]
# Теперь у нас есть алгоритм вывода лучших фич для классификации по мнению ```SelectKBest```. Стоит попробовать произвести классификацию, используя только данные признаки. Но видимо для этого стоит изменить тестовые и тренировочные выборки, оставив только самые необходимые признаки.
#
# Потом этим займемся. Наверное стоит сохранить признаки в список.

# %%
list_feature_K = []
for feature in best_features['number']:
    list_feature_K.append(feature)

# %% [markdown]
# # Классификация с использованием лучших признаков
# Для классификации выберем тот же ```DecisionTreeClassifier```. Нужно создать новые тренировчные выборки, в которых останутся лишь необходимые признаки.

# %%
tx_train = x_train.transpose()
tx_test = x_test.transpose()
new_x_train = []
new_x_test = []
for i in list_feature_K:
    new_x_train.append(tx_train[i])
    new_x_test.append(tx_test[i])
nx_train = np.array(new_x_train, copy=False).transpose()
nx_test = np.array(new_x_test, copy=False).transpose()

# %%
model = DecisionTreeClassifier()
clf = model.fit(nx_train, y_train)

# %%
accuracy = clf.score(nx_test, y_test)
accuracy
# Out:
# 0.7379746784614334

# %% [markdown]
# Результат откровенно говоря не очень. Наверное 20 лучших признаков просто не достаточно в данном случае. Но так или иначе можно приступать к реализации функции, которая покажет оптимальное количество признаков.

# %% [markdown]
# # def FindBestKFeatures
# Функция принимает два аргумента: минамальное количество и максимальное количество признаков, которое нам нужно протестировать. За основу берется тот же алгоритм, что написан выше. Создается **DataFrame**, применяется ```MLPClassifier```, но только дальше берется различное количество наилучших признаков и с помощью кросс-валидации дается итоговая оценка классификации. Функция возвращает два списка: в одном количество взятых признаков, а в другом соответсвующий результат взятому количетсву признаков.

# %%
def FindBestKFeatures(Kmin, Kmax):
    names = []  
    num = []
    results = []
    for i in range(len(x_train[0])):
        names.append(i)

    x = pd.DataFrame(x_train, columns = names)
    y = pd.DataFrame(y_train)
    
    selecter = SelectKBest(score_func=chi2)
    fit = selecter.fit(x.values, y.values)
    all_features = pd.DataFrame(data=fit.scores_, index=x.columns, columns=['score'])
    all_features['number'] = pd.Series(range(x.shape[1]), index=all_features.index)
    
    for K in range (Kmin, Kmax):
        num.append(K)
        best_features = all_features.nlargest(K, "score")
        
        list_feature_K = []
        for feature in best_features['number']:
            list_feature_K.append(feature)
        
        tx_train = x_train.transpose()
        tx_test = x_test.transpose()
        new_x_train = []
        new_x_test = []
        for i in list_feature_K:
            new_x_train.append(tx_train[i])
            new_x_test.append(tx_test[i])
        nx_train = np.array(new_x_train, copy=False).transpose()
        nx_test = np.array(new_x_test, copy=False).transpose()
        
        model = MLPClassifier()
        cvs = cross_val_score(clf, nx_train, y_train, cv=5)
        tmp = sum(cvs)
        res = tmp/len(cvs)
        results.append(res)
        print("Итерация для", K, 'признаков закончена')
    return(num, results)

# %%
num, accuracy = FindBestKFeatures(20, 230)
# Out:
# Итерация для 20 признаков закончена
# Итерация для 21 признаков закончена
# Итерация для 22 признаков закончена
# Итерация для 23 признаков закончена
# Итерация для 24 признаков закончена
# Итерация для 25 признаков закончена
# Итерация для 26 признаков закончена
# Итерация для 27 признаков закончена
# Итерация для 28 признаков закончена
# Итерация для 29 признаков закончена
# Итерация для 30 признаков закончена
# Итерация для 31 признаков закончена
# Итерация для 32 признаков закончена
# Итерация для 33 признаков закончена
# Итерация для 34 признаков закончена
# Итерация для 35 признаков закончена
# Итерация для 36 признаков закончена
# Итерация для 37 признаков закончена
# Итерация для 38 признаков закончена
# Итерация для 39 признаков закончена
# Итерация для 40 признаков закончена
# Итерация для 41 признаков закончена
# Итерация для 42 признаков закончена
# Итерация для 43 признаков закончена
# Итерация для 44 признаков закончена
# Итерация для 45 признаков закончена
# Итерация для 46 признаков закончена
# Итерация для 47 признаков закончена
# Итерация для 48 признаков закончена
# Итерация для 49 признаков закончена
# Итерация для 50 признаков закончена
# Итерация для 51 признаков закончена
# Итерация для 52 признаков закончена
# Итерация для 53 признаков закончена
# Итерация для 54 признаков закончена
# Итерация для 55 признаков закончена
# Итерация для 56 признаков закончена
# Итерация для 57 признаков закончена
# Итерация для 58 признаков закончена
# Итерация для 59 признаков закончена
# Итерация для 60 признаков закончена
# Итерация для 61 признаков закончена
# Итерация для 62 признаков закончена
# Итерация для 63 признаков закончена
# Итерация для 64 признаков закончена
# Итерация для 65 признаков закончена
# Итерация для 66 признаков закончена
# Итерация для 67 признаков закончена
# Итерация для 68 признаков закончена
# Итерация для 69 признаков закончена
# Итерация для 70 признаков закончена
# Итерация для 71 признаков закончена
# Итерация для 72 признаков закончена
# Итерация для 73 признаков закончена
# Итерация для 74 признаков закончена
# Итерация для 75 признаков закончена
# Итерация для 76 признаков закончена
# Итерация для 77 признаков закончена
# Итерация для 78 признаков закончена
# Итерация для 79 признаков закончена
# Итерация для 80 признаков закончена
# Итерация для 81 признаков закончена
# Итерация для 82 признаков закончена
# Итерация для 83 признаков закончена
# Итерация для 84 признаков закончена
# Итерация для 85 признаков закончена
# Итерация для 86 признаков закончена
# Итерация для 87 признаков закончена
# Итерация для 88 признаков закончена
# Итерация для 89 признаков закончена
# Итерация для 90 признаков закончена
# Итерация для 91 признаков закончена
# Итерация для 92 признаков закончена
# Итерация для 93 признаков закончена
# Итерация для 94 признаков закончена
# Итерация для 95 признаков закончена
# Итерация для 96 признаков закончена
# Итерация для 97 признаков закончена
# Итерация для 98 признаков закончена
# Итерация для 99 признаков закончена
# Итерация для 100 признаков закончена
# Итерация для 101 признаков закончена
# Итерация для 102 признаков закончена
# Итерация для 103 признаков закончена
# Итерация для 104 признаков закончена
# Итерация для 105 признаков закончена
# Итерация для 106 признаков закончена
# Итерация для 107 признаков закончена
# Итерация для 108 признаков закончена
# Итерация для 109 признаков закончена
# Итерация для 110 признаков закончена
# Итерация для 111 признаков закончена
# Итерация для 112 признаков закончена
# Итерация для 113 признаков закончена
# Итерация для 114 признаков закончена
# Итерация для 115 признаков закончена
# Итерация для 116 признаков закончена
# Итерация для 117 признаков закончена
# Итерация для 118 признаков закончена
# Итерация для 119 признаков закончена
# Итерация для 120 признаков закончена
# Итерация для 121 признаков закончена
# Итерация для 122 признаков закончена
# Итерация для 123 признаков закончена
# Итерация для 124 признаков закончена
# Итерация для 125 признаков закончена
# Итерация для 126 признаков закончена
# Итерация для 127 признаков закончена
# Итерация для 128 признаков закончена
# Итерация для 129 признаков закончена
# Итерация для 130 признаков закончена
# Итерация для 131 признаков закончена
# Итерация для 132 признаков закончена
# Итерация для 133 признаков закончена
# Итерация для 134 признаков закончена
# Итерация для 135 признаков закончена
# Итерация для 136 признаков закончена
# Итерация для 137 признаков закончена
# Итерация для 138 признаков закончена
# Итерация для 139 признаков закончена
# Итерация для 140 признаков закончена
# Итерация для 141 признаков закончена
# Итерация для 142 признаков закончена
# Итерация для 143 признаков закончена
# Итерация для 144 признаков закончена
# Итерация для 145 признаков закончена
# Итерация для 146 признаков закончена
# Итерация для 147 признаков закончена
# Итерация для 148 признаков закончена
# Итерация для 149 признаков закончена
# Итерация для 150 признаков закончена
# Итерация для 151 признаков закончена
# Итерация для 152 признаков закончена
# Итерация для 153 признаков закончена
# Итерация для 154 признаков закончена
# Итерация для 155 признаков закончена
# Итерация для 156 признаков закончена
# Итерация для 157 признаков закончена
# Итерация для 158 признаков закончена
# Итерация для 159 признаков закончена
# Итерация для 160 признаков закончена
# Итерация для 161 признаков закончена
# Итерация для 162 признаков закончена
# Итерация для 163 признаков закончена
# Итерация для 164 признаков закончена
# Итерация для 165 признаков закончена
# Итерация для 166 признаков закончена
# Итерация для 167 признаков закончена
# Итерация для 168 признаков закончена
# Итерация для 169 признаков закончена
# Итерация для 170 признаков закончена
# Итерация для 171 признаков закончена
# Итерация для 172 признаков закончена
# Итерация для 173 признаков закончена
# Итерация для 174 признаков закончена
# Итерация для 175 признаков закончена
# Итерация для 176 признаков закончена
# Итерация для 177 признаков закончена
# Итерация для 178 признаков закончена
# Итерация для 179 признаков закончена
# Итерация для 180 признаков закончена
# Итерация для 181 признаков закончена
# Итерация для 182 признаков закончена
# Итерация для 183 признаков закончена
# Итерация для 184 признаков закончена
# Итерация для 185 признаков закончена
# Итерация для 186 признаков закончена
# Итерация для 187 признаков закончена
# Итерация для 188 признаков закончена
# Итерация для 189 признаков закончена
# Итерация для 190 признаков закончена
# Итерация для 191 признаков закончена
# Итерация для 192 признаков закончена
# Итерация для 193 признаков закончена
# Итерация для 194 признаков закончена
# Итерация для 195 признаков закончена
# Итерация для 196 признаков закончена
# Итерация для 197 признаков закончена
# Итерация для 198 признаков закончена
# Итерация для 199 признаков закончена
# Итерация для 200 признаков закончена
# Итерация для 201 признаков закончена
# Итерация для 202 признаков закончена
# Итерация для 203 признаков закончена
# Итерация для 204 признаков закончена
# Итерация для 205 признаков закончена
# Итерация для 206 признаков закончена
# Итерация для 207 признаков закончена
# Итерация для 208 признаков закончена
# Итерация для 209 признаков закончена
# Итерация для 210 признаков закончена
# Итерация для 211 признаков закончена
# Итерация для 212 признаков закончена
# Итерация для 213 признаков закончена
# Итерация для 214 признаков закончена
# Итерация для 215 признаков закончена
# Итерация для 216 признаков закончена
# Итерация для 217 признаков закончена
# Итерация для 218 признаков закончена
# Итерация для 219 признаков закончена
# Итерация для 220 признаков закончена
# Итерация для 221 признаков закончена
# Итерация для 222 признаков закончена
# Итерация для 223 признаков закончена
# Итерация для 224 признаков закончена
# Итерация для 225 признаков закончена
# Итерация для 226 признаков закончена
# Итерация для 227 признаков закончена
# Итерация для 228 признаков закончена
# Итерация для 229 признаков закончена

# %% [markdown]
# Извлечем лучший результат

# %%
best = 0
c = 0
numb = 0
for a in accuracy:
    if a > best:
        best = a
        numb = num[c]
    c+=1
print("Лучший результат показали", numb, 'признаков. Accuracy =', best)
# Out:
# Лучший результат показали 167 признаков. Accuracy = 0.7446406728963477

# %% [markdown]
# # Результаты
# ## DataFrame с признаками и их информативностью, отсортированный по убыванию

# %%
best_features
# Out:
#             score  number
# 136  34782.500801     136
# 135  34706.851147     135
# 137  34536.279696     137
# 134  33720.294293     134
# 138  33627.502198     138
# ..            ...     ...
# 111   5305.993090     111
# 69    5286.560921      69
# 107   5240.934829     107
# 110   5229.831857     110
# 41    5194.174652      41
#
# [169 rows x 2 columns]

# %% [markdown]
# ## График, показывающий зависимость результата оценки от числа выбранных признаков

# %%
fig, (ax1) = plt.subplots(nrows=1, ncols=1, figsize=(14, 7), dpi=120)

plt.xlabel("Number of Features")
plt.ylabel("Accuracy")
plt.title("Зависимость результата оценки от числа выбранных признаков")
ax1.plot(num, accuracy)

# %% [markdown]
# ## Таблица содержащая метрики для лучшей модели

# %%
best_features = all_features.nlargest(169, "score")
list_feature_K = []

list_feature_K.append(feature)
        
tx_train = x_train.transpose()
tx_test = x_test.transpose()
new_x_train = []
new_x_test = []
for i in list_feature_K:
    new_x_train.append(tx_train[i])
    new_x_test.append(tx_test[i])
nx_train = np.array(new_x_train, copy=False).transpose()
nx_test = np.array(new_x_test, copy=False).transpose()
        
model = MLPClassifier()
model = model.fit(nx_train, y_train)
pred = model.predict(nx_test)
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      3977
#            5       0.00      0.00      0.00     33709
#            7       0.70      1.00      0.82    173419
#           10       0.00      0.00      0.00     37932
#
#     accuracy                           0.70    249037
#    macro avg       0.17      0.25      0.21    249037
# weighted avg       0.48      0.70      0.57    249037
# C:\Program Files\Anaconda\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Program Files\Anaconda\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Program Files\Anaconda\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## Визуализация предсказания

# %%
cls = MLPClassifier()
cls.fit(x_train, y_train)
cls.score(x_test, y_test)

train_preds = cls.predict(x_train)
test_preds = cls.predict(x_test)

predictions_map = np.zeros_like(mask)

for (y, x), pred in zip(train_indices, train_preds):
    predictions_map[y, x] = pred
    
for (y, x), pred in zip(test_indices, test_preds):
    predictions_map[y, x] = pred
    
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(15, 10))
sns.heatmap(mask, ax=ax1)
sns.heatmap(predictions_map, ax=ax2)
ax1.set_title('Mask')
ax2.set_title('Predictions')
# Out:
# Text(0.5, 1.0, 'Predictions')
